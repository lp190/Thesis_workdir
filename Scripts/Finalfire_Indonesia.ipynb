# %% [markdown]
# # Project Master's Thesis: Forest Fire on Socioeconomic Outcomes in Indonesia
# ## Author: Lokesh Pandey
# ### Date: 10.02.2025

# %%
import os
import geopandas as gpd
import pandas as pd

# %%
# Load final forest fire data in Indonesia
indonesia_fire = gpd.read_file("../../Data/GWIS_2021_Final/Indonesia_final/combined/combined_fires_indonesia_final.shp")

# %%
# Explore
#indonesia_fire.shape # Total of 198200 toal fires from 2000 to 2021

indonesia_fire
# Out:
#               Id      IDate      FDate  index_righ GID_0    COUNTRY  \
# 0       17475778 2014-08-20 2014-09-22           0   IDN  Indonesia
# 1       17475797 2014-08-23 2014-09-15           0   IDN  Indonesia
# 2       17475989 2014-08-31 2014-09-22           0   IDN  Indonesia
# 3       17476027 2014-08-30 2014-09-25           0   IDN  Indonesia
# 4       17476701 2014-08-21 2014-09-18           0   IDN  Indonesia
# ...          ...        ...        ...         ...   ...        ...
# 198195  10435335 2008-09-09 2008-09-14           0   IDN  Indonesia
# 198196  10435337 2008-09-06 2008-09-06           0   IDN  Indonesia
# 198197  10435341 2008-09-12 2008-09-12           0   IDN  Indonesia
# 198198  10435344 2008-09-13 2008-09-13           0   IDN  Indonesia
# 198199  10435353 2008-09-09 2008-09-09           0   IDN  Indonesia
#
#                                                  geometry
# 0       MULTIPOLYGON (((105.33248 -2.43333, 105.32831 ...
# ...

# %%
#
